# %% [markdown]
# <a href="https://colab.research.google.com/github/coulibalymoumouni/Python_seance/blob/main/python_seance_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#chargement du fichier
import pandas as pd
#nomme notre fichier df comme dataframe (tableau à 2 dimensions)
df = pd.read_excel('/content/sample_data/diabete.xlsx')

# %%
#afficher les 5 premières lignes de notre fichier
df.head(5)
# Out:
#    pregnant  plasma  diastolic  triceps  serum  bodymass  pedigree  age  \
# 0         0     138          0        0      0      36.3     0.933   25
# 1         4     142         86        0      0      44.0     0.645   22
# 2         3     142         80       15      0      32.4     0.200   63
# 3         3     113         50       10     85      29.5     0.626   25
# 4         5      88         78       30      0      27.6     0.258   37
#
#    alea1  alea2   diabete
# 0  0.338  0.188  positive
# 1  0.835  0.711  positive
# 2  0.493  0.845  negative
# 3  0.857  0.821  negative
# 4  0.045  0.392  negative

# %%
# @title pregnant

from matplotlib import pyplot as plt
df['pregnant'].plot(kind='hist', bins=20, title='pregnant')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#import du fichier csv à partir du site internet
df2 = pd.read_csv('https://www.data.gouv.fr/en/datasets/r/08c18e08-6780-452d-9b8c-ae244ad529b3',sep=";")
df2.head()
# Out:
#    reg  cl_age90        jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc
# 0    1         0  2020-03-18     0    0       NaN       NaN     NaN    0   0
# 1    1         9  2020-03-18     0    0       NaN       NaN     NaN    0   0
# 2    1        19  2020-03-18     0    0       NaN       NaN     NaN    0   0
# 3    1        29  2020-03-18     0    0       NaN       NaN     NaN    0   0
# 4    1        39  2020-03-18     0    0       NaN       NaN     NaN    0   0

# %%
#nombre de lignes et de colonnes de mon fichier
df.shape
# Out:
# (568, 11)

# %%
#afficher la liste des variables
listevariable = df.columns
print(listevariable)
# Out:
# Index(['pregnant', 'plasma', 'diastolic', 'triceps', 'serum', 'bodymass',
#        'pedigree', 'age', 'alea1', 'alea2', 'diabete'],
#       dtype='object')

# %%
#afficher le type des variables
df.dtypes
# Out:
# pregnant       int64
# plasma         int64
# diastolic      int64
# triceps        int64
# serum          int64
# bodymass     float64
# pedigree     float64
# age            int64
# alea1        float64
# alea2        float64
# diabete       object
# dtype: object

# %%
#je veux regrouper :
#le nombre de variables, le type de variables, et les observations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pregnant   568 non-null    int64
#  1   plasma     568 non-null    int64
#  2   diastolic  568 non-null    int64
#  3   triceps    568 non-null    int64
#  4   serum      568 non-null    int64
#  5   bodymass   568 non-null    float64
#  6   pedigree   568 non-null    float64
#  7   age        568 non-null    int64
#  8   alea1      568 non-null    float64
#  9   alea2      568 non-null    float64
#  10  diabete    568 non-null    object
# dtypes: float64(4), int64(6), object(1)
# memory usage: 48.9+ KB

# %%
#je veux afficher uniquement 2 variables
print(df[['serum','plasma']])
# Out:
#      serum  plasma
# 0        0     138
# 1        0     142
# 2        0     142
# 3       85     113
# 4        0      88
# ..     ...     ...
# 563      0     128
# 564    105     130
# 565      0     117
# 566    310     143
# 567     50     119
#
# [568 rows x 2 columns]

# %%
#je veux afficher les premières lignes mais uniquement serum et plasma
df[['serum','plasma']].head(8)
# Out:
#    serum  plasma
# 0      0     138
# 1      0     142
# 2      0     142
# 3     85     113
# 4      0      88
# 5    125     110
# 6      0     129
# 7      0      57
